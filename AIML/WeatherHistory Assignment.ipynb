# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
Weather=pd.read_csv(r"C:\Users\roopa\Desktop\Veer_Trainings\Python, AIML, DS\AIML\weatherHistory - Assignment.csv")
Weather
# Out:
#              Summary Precip Type  Humidity  Wind Speed (km/h)  \
# 0      Partly Cloudy        rain      0.89            14.1197
# 1      Partly Cloudy        rain      0.86            14.2646
# 2      Mostly Cloudy        rain      0.89             3.9284
# 3      Partly Cloudy        rain      0.83            14.1036
# 4      Mostly Cloudy        rain      0.83            11.0446
# ...              ...         ...       ...                ...
# 96448  Partly Cloudy        rain      0.43            10.9963
# 96449  Partly Cloudy        rain      0.48            10.0947
# 96450  Partly Cloudy        rain      0.56             8.9838
# 96451  Partly Cloudy        rain      0.60            10.5294
# 96452  Partly Cloudy        rain      0.61             5.8765
#
#        Wind Bearing (degrees)  Visibility (km)  Loud Cover  \
# 0                         251          15.8263           0
# 1                         259          15.8263           0
# ...

# %%
#DV -> Temperature
#IV-> Summary, PrecipType, Humidity, Wind Bearing, Visibility, LoudCover, Pressure, Daily Summary
Weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96453 entries, 0 to 96452
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Summary                 96453 non-null  object
#  1   Precip Type             95936 non-null  object
#  2   Humidity                96453 non-null  float64
#  3   Wind Speed (km/h)       96453 non-null  float64
#  4   Wind Bearing (degrees)  96453 non-null  int64
#  5   Visibility (km)         96453 non-null  float64
#  6   Loud Cover              96453 non-null  int64
#  7   Pressure (millibars)    96453 non-null  float64
#  8   Daily Summary           96453 non-null  object
#  9   Temperature (C)         96453 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 7.4+ MB

# %%
# Weather['Summary'].unique(), totally useless for analysis, as this is also a DV

# %%
# Weather['Daily Summary'].unique(), totally useless as this is also a DV

# %%
# Weather['Precip Type'].unique(), is useful as we have only 2 categories

# %%
Weather=Weather.drop(['Summary','Daily Summary'],axis=1)
Weather
# Out:
#       Precip Type  Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  \
# 0            rain      0.89            14.1197                     251
# 1            rain      0.86            14.2646                     259
# 2            rain      0.89             3.9284                     204
# 3            rain      0.83            14.1036                     269
# 4            rain      0.83            11.0446                     259
# ...           ...       ...                ...                     ...
# 96448        rain      0.43            10.9963                      31
# 96449        rain      0.48            10.0947                      20
# 96450        rain      0.56             8.9838                      30
# 96451        rain      0.60            10.5294                      20
# 96452        rain      0.61             5.8765                      39
#
#        Visibility (km)  Loud Cover  Pressure (millibars)  Temperature (C)
# ...

# %%
Weather['Precip Type']=Weather['Precip Type'].astype('category')
Weather['Precip Type']=Weather['Precip Type'].cat.codes
Weather
# Out:
#        Precip Type  Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  \
# 0                0      0.89            14.1197                     251
# 1                0      0.86            14.2646                     259
# 2                0      0.89             3.9284                     204
# 3                0      0.83            14.1036                     269
# 4                0      0.83            11.0446                     259
# ...            ...       ...                ...                     ...
# 96448            0      0.43            10.9963                      31
# 96449            0      0.48            10.0947                      20
# 96450            0      0.56             8.9838                      30
# 96451            0      0.60            10.5294                      20
# 96452            0      0.61             5.8765                      39
#
#        Visibility (km)  Loud Cover  Pressure (millibars)  Temperature (C)
# ...

# %%
Weather.isna().sum()
# Out:
# Precip Type               0
# Humidity                  0
# Wind Speed (km/h)         0
# Wind Bearing (degrees)    0
# Visibility (km)           0
# Loud Cover                0
# Pressure (millibars)      0
# Temperature (C)           0
# dtype: int64

# %%
del Weather['Loud Cover']

# %%
Weather
# Out:
#        Precip Type  Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  \
# 0                0      0.89            14.1197                     251
# 1                0      0.86            14.2646                     259
# 2                0      0.89             3.9284                     204
# 3                0      0.83            14.1036                     269
# 4                0      0.83            11.0446                     259
# ...            ...       ...                ...                     ...
# 96448            0      0.43            10.9963                      31
# 96449            0      0.48            10.0947                      20
# 96450            0      0.56             8.9838                      30
# 96451            0      0.60            10.5294                      20
# 96452            0      0.61             5.8765                      39
#
#        Visibility (km)  Pressure (millibars)  Temperature (C)
# ...

# %%
Weather.iloc[:,:6].corr()
# Out:
#                         Precip Type  Humidity  Wind Speed (km/h)  \
# Precip Type                1.000000  0.223896          -0.068319
# Humidity                   0.223896  1.000000          -0.224951
# Wind Speed (km/h)         -0.068319 -0.224951           1.000000
# Wind Bearing (degrees)    -0.040390  0.000735           0.103822
# Visibility (km)           -0.291999 -0.369173           0.100749
# Pressure (millibars)       0.006472  0.005454          -0.049263
#
#                         Wind Bearing (degrees)  Visibility (km)  \
# Precip Type                          -0.040390        -0.291999
# Humidity                              0.000735        -0.369173
# Wind Speed (km/h)                     0.103822         0.100749
# Wind Bearing (degrees)                1.000000         0.047594
# Visibility (km)                       0.047594         1.000000
# Pressure (millibars)                 -0.011651         0.059818
#
#                         Pressure (millibars)
# ...

# %%
# we are good to go for IV and DV split
X=Weather.iloc[:,:6]
Y=Weather.iloc[:,6]
X,Y
# Out:
# (       Precip Type  Humidity  Wind Speed (km/h)  Wind Bearing (degrees)  \
#  0                0      0.89            14.1197                     251
#  1                0      0.86            14.2646                     259
#  2                0      0.89             3.9284                     204
#  3                0      0.83            14.1036                     269
#  4                0      0.83            11.0446                     259
#  ...            ...       ...                ...                     ...
#  96448            0      0.43            10.9963                      31
#  96449            0      0.48            10.0947                      20
#  96450            0      0.56             8.9838                      30
#  96451            0      0.60            10.5294                      20
#  96452            0      0.61             5.8765                      39
#
#         Visibility (km)  Pressure (millibars)
# ...

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,train_size=0.9)

# %%
lin_reg=LinearRegression()
lin_reg.fit(X_train,Y_train)
Y_pred=lin_reg.predict(X_test)

# %%
r2_score(Y_test,Y_pred)
# Out:
# 0.5981379021252431
